# %%
#hide
# !pip install -Uqq fastbook
import fastbook
fastbook.setup_book()

# %%
#hide
from fastbook import *
from fastai.vision.widgets import *

# %% [markdown]
# # From Model to Production

# %% [markdown]
# ## The Practice of Deep Learning

# %% [markdown]
# ### Starting Your Project

# %% [markdown]
# ### The State of Deep Learning

# %% [markdown]
# #### Computer vision

# %% [markdown]
# #### Text (natural language processing)

# %% [markdown]
# #### Combining text and images

# %% [markdown]
# #### Tabular data

# %% [markdown]
# #### Recommendation systems

# %% [markdown]
# #### Other data types

# %% [markdown]
# ### The Drivetrain Approach

# %% [markdown]
# ## Gathering Data

# %% [markdown]
# # clean
# To download images with Bing Image Search, sign up at [Microsoft Azure](https://azure.microsoft.com/en-us/services/cognitive-services/bing-web-search-api/) for a free account. You will be given a key, which you can copy and enter in a cell as follows (replacing 'XXX' with your key and executing it):

# %%
# !pip install bing-image-downloader
# Out:
# Requirement already satisfied: bing-image-downloader in /opt/conda/envs/fastai/lib/python3.8/site-packages (1.1.1)

# %%
from bing_image_downloader import downloader
for q in ['peacock','parrot','crow']:
    downloader.download(q, limit=50, output_dir='birds', adult_filter_off=True, force_replace=False, timeout=5)
# Out:
# [%] Downloading Images to /notebooks/clean/birds/peacock
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 50 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://i.pinimg.com/originals/a5/76/75/a576754a22b43c46dfcdc220b8c30623.png
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://thumbs.dreamstime.com/z/all-peacocks-proud-to-show-off-their-beautiful-feathers-love-handsome-boy-s-stance-definitely-attentive-to-being-128611926.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://cdn.thinglink.me/api/image/644400173409107969/1024/10/scaletowidth/0/0/1/1/false/true?wait=true
# [%] File Downloaded !
#
# [%] Downloading Image #4 from http://4.bp.blogspot.com/-o6JM4bDtUsg/UIVe9SrgVoI/AAAAAAAADLo/ZtsMAStcuRU/s1600/Peafowl.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from http://2.bp.blogspot.com/-jEps9K8gfOM/UZTQL9CxpsI/AAAAAAAABaw/1xtf1BA1Dyo/s1600/peacock.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://2.bp.blogspot.com/_2wyePCMy0iI/TRJo0gdiLEI/AAAAAAAAAfA/UbsqC6tvTFE/s1600/Peacock+gettin+in+my+face.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #7 from https://devino.com/wp-content/uploads/2020/08/Peacock.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #8 from https://www.whats-your-sign.com/wp-content/uploads/2018/02/PeacockSymbolism.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #9 from http://2.bp.blogspot.com/-4ugwW2mChh4/T7gDHm2OQdI/AAAAAAAACOw/H-fmn2mEEhc/s1600/Peacock-Symbolism.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #10 from https://i.pinimg.com/originals/67/ba/da/67badada4af2ad2e981fdc8331cdc5e5.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #11 from https://i.pinimg.com/originals/31/5a/96/315a96d4fb1e7d79b1cbfc02fef8f38d.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #12 from https://i.pinimg.com/736x/15/05/91/150591bfcd9827f0177d92acc3d7721e.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #13 from https://i.pinimg.com/originals/e1/d3/e3/e1d3e35a61b4d9f85190722fed09e3e0.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #14 from https://images.saymedia-content.com/.image/t_share/MTc2Mjg1NTQyMTY4NzMyODYy/the-true-meaning-behind-katy-perrys-peacock.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #15 from https://www.theindiaprint.com/uploads/images/2020/12/dsc100784871_750x500_5fe0f12db0888.jpg
# [Error]Invalid image, not saving https://www.theindiaprint.com/uploads/images/2020/12/dsc100784871_750x500_5fe0f12db0888.jpg
#
# [!] Issue getting: https://www.theindiaprint.com/uploads/images/2020/12/dsc100784871_750x500_5fe0f12db0888.jpg
# [!] Error:: Invalid image, not saving https://www.theindiaprint.com/uploads/images/2020/12/dsc100784871_750x500_5fe0f12db0888.jpg
#
# [%] Downloading Image #15 from https://i.pinimg.com/originals/18/51/3c/18513c3efc6675d0f36f7c845144bc64.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #16 from https
# [%] File Downloaded !
#
# [%] Downloading Image #39 from https://4.bp.blogspot.com/-5_N-2TymxTU/TV0pd61KSyI/AAAAAAAAAG8/pLFLh-vhAjg/s1600/001.JPG
# [%] File Downloaded !
#
# [%] Downloading Image #40 from http://images1.fanpop.com/images/photos/2500000/The-Crow-the-crow-2523255-1280-768.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #41 from https://i.pinimg.com/originals/e3/b2/ed/e3b2ed344dd5c74a64ae3aad5bb48079.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #42 from https://gamepedia.cursecdn.com/dota2_gamepedia/d/d1/Cosmetic_icon_True_Crow's_Wings.png
# [%] File Downloaded !
#
# [%] Downloading Image #43 from https://db4sgowjqfwig.cloudfront.net/images/4485478/591745B6-FC71-4E6E-90C0-74D662828E36.png
# [%] File Downloaded !
#
# [%] Downloading Image #44 from https://i.ytimg.com/vi/dbgSVAwSj7I/maxresdefault.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #45 from https://i.pinimg.com/originals/c9/93/06/c99306aa8b4cb23c12f2d9e8cbd9fc98.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #46 from https://i.pinimg.com/736x/78/59/d2/7859d238baf19d0e96257cdcb77eebfb--pit-bull-dogs-pit-bull-terriers.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #47 from https://www.gravelcyclist.com/wp-content/uploads/2021/03/CroweGravelBikePR2021-4.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 35 Images on Page 2.
#
# ===============================================
#
# [%] Downloading Image #48 from https://d1o50x50snmhul.cloudfront.net/wp-content/uploads/2016/09/14153747/t16_0474a_036.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #49 from https://stillunfold.com/public/upload/story_images/36_2327_post_media_oNjO.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #50 from https://i.pinimg.com/originals/e9/8f/a7/e98fa7523b60304d8c115ba15ffe110e.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 50 images.
# ===============================================
#
# Please show your support here
# https://www.buymeacoffee.com/gurugaurav
#
# ===============================================

# %%
import os
key = os.environ.get('AZURE_SEARCH_KEY', 'XXX')

# %%
search_images_bing

# %%
results = search_images_bing(key, 'grizzly bear')
ims = results.attrgot('contentUrl')
len(ims)

# %%
#hide
ims = ['https://devino.com/wp-content/uploads/2020/08/Peacock.jpg']

# %%
dest = 'images/peacock.jpg'
download_url(ims[0], dest)

# %%
im = Image.open(dest)
im.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x80 at 0x7FDAF0F962B0>

# %%
bird_types = 'peacock','parrot','crow'
path = Path('birds')

# %%
if not path.exists():
    path.mkdir()
    for o in bird_types:
        dest = (path/o)
        dest.mkdir(exist_ok=True)
        results = search_images_bing(key, f'{o} bird')
        download_images(dest, urls=results.attrgot('contentUrl'))

# %%
fns = get_image_files(path)
fns
# Out:
# (#303) [Path('birds/crow/Image_32.jpg'),Path('birds/crow/Image_100.jpg'),Path('birds/crow/Image_93.jpg'),Path('birds/crow/Image_61.jpg'),Path('birds/crow/Image_30.jpg'),Path('birds/crow/Image_73.jpg'),Path('birds/crow/Image_29.jpg'),Path('birds/crow/Image_76.jpg'),Path('birds/crow/Image_69.png'),Path('birds/crow/Image_2.jpg')...]

# %%
failed = verify_images(fns)
failed
# Out:
# (#0) []

# %%
failed.map(Path.unlink);

# %% [markdown]
# ### Sidebar: Getting Help in Jupyter Notebooks

# %% [markdown]
# ### End sidebar

# %% [markdown]
# ## From Data to DataLoaders

# %%
birds = DataBlock(
    blocks=(ImageBlock, CategoryBlock), 
    get_items=get_image_files, 
    splitter=RandomSplitter(valid_pct=0.2, seed=42),
    get_y=parent_label,
    item_tfms=Resize(128))

# %%
dls = birds.dataloaders(path)

# %%
dls.valid.show_batch(max_n=4, nrows=1)

# %%
birds = birds.new(item_tfms=Resize(128, ResizeMethod.Squish))
dls = birds.dataloaders(path)
dls.valid.show_batch(max_n=4, nrows=1)

# %%
birds = birds.new(item_tfms=Resize(128, ResizeMethod.Pad, pad_mode='zeros'))
dls = birds.dataloaders(path)
dls.valid.show_batch(max_n=4, nrows=1)

# %%
birds = birds.new(item_tfms=RandomResizedCrop(128, min_scale=0.3))
dls = birds.dataloaders(path)
dls.train.show_batch(max_n=4, nrows=1, unique=True)

# %% [markdown]
# ### Data Augmentation

# %%
birds = birds.new(item_tfms=Resize(128), batch_tfms=aug_transforms(mult=2))
dls = birds.dataloaders(path)
dls.train.show_batch(max_n=8, nrows=2, unique=True)

# %% [markdown]
# ## Training Your Model, and Using It to Clean Your Data

# %%
birds = birds.new(
    item_tfms=RandomResizedCrop(224, min_scale=0.5),
    batch_tfms=aug_transforms())
dls = birds.dataloaders(path)

# %%
learn = cnn_learner(dls, resnet18, metrics=error_rate)
learn.fine_tune(4)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-5c106cde.pth" to /root/.cache/torch/hub/checkpoints/resnet18-5c106cde.pth
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=46827520.0), HTML(value='')))
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.682695</td>
#       <td>2.402046</td>
#       <td>0.616667</td>
#       <td>00:06</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.993128</td>
#       <td>1.127406</td>
#       <td>0.466667</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.751793</td>
#       <td>0.436261</td>
#       <td>0.133333</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.570593</td>
#       <td>0.292002</td>
#       <td>0.100000</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.469209</td>
#       <td>0.231957</td>
#       <td>0.100000</td>
#       <td>00:07</td>
#     </tr>
#   </tbody>
# </table>

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix()

# %%
interp.plot_top_losses(5, nrows=1)

# %%
cleaner = ImageClassifierCleaner(learn)
cleaner
# Out:
# VBox(children=(Dropdown(options=('crow', 'parrot', 'peacock'), value='crow'), Dropdown(options=('Train', 'Vali…

# %%
#hide
# for idx in cleaner.delete(): cleaner.fns[idx].unlink()
# for idx,cat in cleaner.change(): shutil.move(str(cleaner.fns[idx]), path/cat)

# %% [markdown]
# ## Turning Your Model into an Online Application

# %% [markdown]
# ### Using the Model for Inference

# %%
learn.export()

# %%
path = Path()
path.ls(file_exts='.pkl')
# Out:
# (#1) [Path('export.pkl')]

# %%
learn_inf = load_learner(path/'export.pkl')

# %%
learn_inf.predict('images/peacock.jpg')
# Out:
# ('peacock', TensorImage(2), TensorImage([1.1935e-06, 7.7503e-06, 9.9999e-01]))

# %%
learn_inf.dls.vocab
# Out:
# ['crow', 'parrot', 'peacock']

# %% [markdown]
# ### Creating a Notebook App from the Model

# %%
btn_upload = widgets.FileUpload()
btn_upload
# Out:
# FileUpload(value={}, description='Upload')

# %%
#hide
# For the book, we can't actually click an upload button, so we fake it
btn_upload = SimpleNamespace(data = ['images/peacock.jpg'])

# %%
img = PILImage.create(btn_upload.data[-1])

# %%
out_pl = widgets.Output()
out_pl.clear_output()
with out_pl: display(img.to_thumb(128,128))
out_pl
# Out:
# Output()

# %%
pred,pred_idx,probs = learn_inf.predict(img)

# %%
lbl_pred = widgets.Label()
lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'
lbl_pred
# Out:
# Label(value='Prediction: peacock; Probability: 1.0000')

# %%
btn_run = widgets.Button(description='Classify')
btn_run
# Out:
# Button(description='Classify', style=ButtonStyle())

# %%
def on_click_classify(change):
    img = PILImage.create(btn_upload.data[-1])
    out_pl.clear_output()
    with out_pl: display(img.to_thumb(128,128))
    pred,pred_idx,probs = learn_inf.predict(img)
    lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'

btn_run.on_click(on_click_classify)

# %%
#hide
#Putting back btn_upload to a widget for next cell
btn_upload = widgets.FileUpload()

# %%
VBox([widgets.Label('Select your bird!'), 
      btn_upload, btn_run, out_pl, lbl_pred])
# Out:
# VBox(children=(Label(value='Select your bird!'), FileUpload(value={}, description='Upload'), Button(descriptio…

# %% [markdown]
# ### Turning Your Notebook into a Real App

# %%
#hide
# !pip install voila
# !jupyter serverextension enable --sys-prefix voila
# Out:
# Collecting voila
#   Downloading voila-0.2.10-py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 26.4 MB/s eta 0:00:01
# Requirement already satisfied: jupyter-client<7,>=6.1.3 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from voila) (6.1.7)
# Collecting jupyter-server<2.0.0,>=0.3.0
#   Downloading jupyter_server-1.10.2-py3-none-any.whl (392 kB)
#      |████████████████████████████████| 392 kB 26.9 MB/s eta 0:00:01
# Collecting nbconvert<7,>=6.0.0
#   Downloading nbconvert-6.1.0-py3-none-any.whl (551 kB)
#      |████████████████████████████████| 551 kB 28.8 MB/s eta 0:00:01
# Requirement already satisfied: nbclient<0.6,>=0.4.0 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from voila) (0.5.1)
# Requirement already satisfied: pyzmq>=13 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from jupyter-client<7,>=6.1.3->voila) (20.0.0)
# Requirement already satisfied: tornado>=4.1 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from jupyter-client<7,>=6.1.3->voila) (6.1)
# Requirement already satisfied: python-dateutil>=2.1 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from jupyter-client<7,>=6.1.3->voila) (2.8.1)
# Requirement already satisfied: jupyter-core>=4.6.0 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from jupyter-client<7,>=6.1.3->voila) (4.7.0)
# Requirement already satisfied: traitlets in /opt/conda/envs/fastai/lib/python3.8/site-packages (from jupyter-client<7,>=6.1.3->voila) (5.0.5)
# Requirement already satisfied: terminado>=0.8.3 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (0.9.1)
# Requirement already satisfied: prometheus-client in /opt/conda/envs/fastai/lib/python3.8/site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (0.9.0)
# Requirement already satisfied: argon2-cffi in /opt/conda/envs/fastai/lib/python3.8/site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (20.1.0)
# Collecting websocket-client
#   Downloading websocket_client-1.2.1-py2.py3-none-any.whl (52 kB)
#      |████████████████████████████████| 52 kB 3.6 MB/s  eta 0:00:01
# Requirement already satisfied: jinja2 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (2.11.2)
# Requirement already satisfied: ipython-genutils in /opt/conda/envs/fastai/lib/python3.8/site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (0.2.0)
# Requirement already satisfied: Send2Trash in /opt/conda/envs/fastai/lib/python3.8/site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (1.5.0)
# Collecting requests-unixsocket
#   Downloading requests_unixsocket-0.2.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: nbformat in /opt/conda/envs/fastai/lib/python3.8/site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (5.0.8)
# Collecting anyio<4,>=3.1.0
#   Downloading anyio-3.3.0-py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 12.5 MB/s eta 0:00:01
# Requirement already satisfied: pygments>=2.4.1 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from nbconvert<7,>=6.0.0->voila) (2.7.2)
# Requirement already satisfied: jupyterlab-pygments in /opt/conda/envs/fastai/lib/python3.8/site-packages (from nbconvert<7,>=6.0.0->voila) (0.1.2)
# Requirement already satisfied: defusedxml in /opt/conda/envs/fastai/lib/python3.8/site-packages (from nbconvert<7,>=6.0.0->voila) (0.6.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from nbconvert<7,>=6.0.0->voila) (1.4.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from nbconvert<7,>=6.0.0->voila) (0.8.4)
# Requirement already satisfied: testpath in /opt/conda/envs/fastai/lib/python3.8/site-packages (from nbconvert<7,>=6.0.0->voila) (0.4.4)
# Requirement already satisfied: bleach in /opt/conda/envs/fastai/lib/python3.8/site-packages (from nbconvert<7,>=6.0.0->voila) (3.2.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from nbconvert<7,>=6.0.0->voila) (0.3)
# Requirement already satisfied: nest-asyncio in /opt/conda/envs/fastai/lib/python3.8/site-packages (from nbclient<0.6,>=0.4.0->voila) (1.4.3)
# Requirement already satisfied: async-generator in /opt/conda/envs/fastai/lib/python3.8/site-packages (from nbclient<0.6,>=0.4.0->voila) (1.10)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from python-dateutil>=2.1->jupyter-client<7,>=6.1.3->voila) (1.15.0)
# Requirement already satisfied: ptyprocess; os_name != "nt" in /opt/conda/envs/fastai/lib/python3.8/site-packages (from terminado>=0.8.3->jupyter-server<2.0.0,>=0.3.0->voila) (0.6.0)
# Requirement already satisfied: cffi>=1.0.0 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from argon2-cffi->jupyter-server<2.0.0,>=0.3.0->voila) (1.14.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from jinja2->jupyter-server<2.0.0,>=0.3.0->voila) (1.1.1)
# Requirement already satisfied: requests>=1.1 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from requests-unixsocket->jupyter-server<2.0.0,>=0.3.0->voila) (2.25.0)
# Requirement already satisfied: urllib3>=1.8 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from requests-unixsocket->jupyter-server<2.0.0,>=0.3.0->voila) (1.25.11)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from nbformat->jupyter-server<2.0.0,>=0.3.0->voila) (3.2.0)
# Requirement already satisfied: idna>=2.8 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from anyio<4,>=3.1.0->jupyter-server<2.0.0,>=0.3.0->voila) (2.10)
# Collecting sniffio>=1.1
#   Downloading sniffio-1.2.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: webencodings in /opt/conda/envs/fastai/lib/python3.8/site-packages (from bleach->nbconvert<7,>=6.0.0->voila) (0.5.1)
# Requirement already satisfied: packaging in /opt/conda/envs/fastai/lib/python3.8/site-packages (from bleach->nbconvert<7,>=6.0.0->voila) (20.4)
# Requirement already satisfied: pycparser in /opt/conda/envs/fastai/lib/python3.8/site-packages (from cffi>=1.0.0->argon2-cffi->jupyter-server<2.0.0,>=0.3.0->voila) (2.20)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from requests>=1.1->requests-unixsocket->jupyter-server<2.0.0,>=0.3.0->voila) (2020.11.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from requests>=1.1->requests-unixsocket->jupyter-server<2.0.0,>=0.3.0->voila) (3.0.4)
# Requirement already satisfied: pyrsistent>=0.14.0 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->jupyter-server<2.0.0,>=0.3.0->voila) (0.17.3)
# Requirement already satisfied: setuptools in /opt/conda/envs/fastai/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->jupyter-server<2.0.0,>=0.3.0->voila) (49.6.0.post20201009)
# Requirement already satisfied: attrs>=17.4.0 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->jupyter-server<2.0.0,>=0.3.0->voila) (20.3.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/conda/envs/fastai/lib/python3.8/site-packages (from packaging->bleach->nbconvert<7,>=6.0.0->voila) (2.4.7)
# Installing collected packages: websocket-client, requests-unixsocket, nbconvert, sniffio, anyio, jupyter-server, voila
#   Attempting uninstall: nbconvert
#     Found existing installation: nbconvert 5.6.1
#     Uninstalling nbconvert-5.6.1:
#       Successfully uninstalled nbconvert-5.6.1
# ERROR: After October 2020 you may experience errors when installing or updating packages. This is because pip will change the way that it resolves dependency conflicts.
#
# We recommend you use --use-feature=2020-resolver to test your packages with the new resolver before it becomes the default.
#
# nbdev 1.1.5 requires nbconvert<6, but you'll have nbconvert 6.1.0 which is incompatible.
# Successfully installed anyio-3.3.0 jupyter-server-1.10.2 nbconvert-6.1.0 requests-unixsocket-0.2.0 sniffio-1.2.0 voila-0.2.10 websocket-client-1.2.1
# Enabling: voila
# - Writing config: /opt/conda/envs/fastai/etc/jupyter
#     - Validating...
#       voila 0.2.10 OK

# %% [markdown]
# ### Deploying your app

# %%
learn.export()

# %% [markdown]
# ## How to Avoid Disaster

# %%
path = Path()
path.ls(file_exts='.pkl')
# Out:
# (#1) [Path('export.pkl')]

# %% [markdown]
# ### Unforeseen Consequences and Feedback Loops

# %% [markdown]
# ## Get Writing!

# %% [markdown]
# ## Questionnaire

# %% [markdown]
# 1. Provide an example of where the bear classification model might work poorly in production, due to structural or style differences in the training data.
# 1. Where do text models currently have a major deficiency?
# 1. What are possible negative societal implications of text generation models?
# 1. In situations where a model might make mistakes, and those mistakes could be harmful, what is a good alternative to automating a process?
# 1. What kind of tabular data is deep learning particularly good at?
# 1. What's a key downside of directly using a deep learning model for recommendation systems?
# 1. What are the steps of the Drivetrain Approach?
# 1. How do the steps of the Drivetrain Approach map to a recommendation system?
# 1. Create an image recognition model using data you curate, and deploy it on the web.
# 1. What is `DataLoaders`?
# 1. What four things do we need to tell fastai to create `DataLoaders`?
# 1. What does the `splitter` parameter to `DataBlock` do?
# 1. How do we ensure a random split always gives the same validation set?
# 1. What letters are often used to signify the independent and dependent variables?
# 1. What's the difference between the crop, pad, and squish resize approaches? When might you choose one over the others?
# 1. What is data augmentation? Why is it needed?
# 1. What is the difference between `item_tfms` and `batch_tfms`?
# 1. What is a confusion matrix?
# 1. What does `export` save?
# 1. What is it called when we use a model for getting predictions, instead of training?
# 1. What are IPython widgets?
# 1. When might you want to use CPU for deployment? When might GPU be better?
# 1. What are the downsides of deploying your app to a server, instead of to a client (or edge) device such as a phone or PC?
# 1. What are three examples of problems that could occur when rolling out a bear warning system in practice?
# 1. What is "out-of-domain data"?
# 1. What is "domain shift"?
# 1. What are the three steps in the deployment process?

# %% [markdown]
# ### Further Research

# %% [markdown]
# 1. Consider how the Drivetrain Approach maps to a project or problem you're interested in.
# 1. When might it be best to avoid certain types of data augmentation?
# 1. For a project you're interested in applying deep learning to, consider the thought experiment "What would happen if it went really, really well?"
# 1. Start a blog, and write your first blog post. For instance, write about what you think deep learning might be useful for in a domain you're interested in.
